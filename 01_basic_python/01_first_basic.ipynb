# %%
age = 23
height = 5.8
name = "Shani"
is_developer = True

print(age, type(age))
print(height, type(height))
print(name, type(name))
print(is_developer, type(is_developer))
# Out:
# 23 <class 'int'>
# 5.8 <class 'float'>
# Shani <class 'str'>
# True <class 'bool'>
